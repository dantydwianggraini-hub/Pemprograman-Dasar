# %% [markdown]
# <a href="https://colab.research.google.com/github/dantydwianggraini-hub/Pemprograman-Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "Danty d. Anggraini"
umur = 20
jurusan = "Elektro"
prodi = "RPE"
semester = 3
matakuliah = "Pemerograman Dasar"
status_kelulusan = False

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_kelulusan)
# Out:
# Danty d. Anggraini
# 20
# Elektro
# RPE
# 3
# Pemerograman Dasar
# False
